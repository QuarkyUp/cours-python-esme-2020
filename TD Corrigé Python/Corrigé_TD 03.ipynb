# %% [markdown]
# ***
# # IAS1 Corrigé TD 03 - Les structures de répétition
# ***

# %% [markdown]
# ***
# ### Tests automatiques

# %%
# Exécutez cette cellule pour charger le script de tests automatiques du TD
import sys
sys.path.append('Tests_TD')
import TestsTD3

# %% [markdown]
# ***
# ## Exercice 03.1
# ***

# %% [markdown]
# Ecrivez un programme qui demande un nombre (entier ou réel) à rentrer au clavier tant que celui-ci n’est pas négatif.

# %%
x = int(input("Donnez un nombre négatif :"))

while x >= 0:
    x = int(input("Donnez un nombre négatif :"))
    
print ("Merci !")

# %% [markdown]
# ***
# ## Exercice 03.2
# ***

# %% [markdown]
# Ecrivez un programme qui affiche variable `somme_entiers` correspondant à la somme des entiers de 3 à 172, c'est à dire 3 + 4 + 5 + ... + 171 + 172.

# %%
somme_entiers=0

for i in range (3,173):
    somme_entiers += i
 
print(somme_entiers)

# %% [markdown]
# ### *Test*

# %%
""" Test la valeur de somme_entiers """
variables = globals().copy().items()
TestsTD3.exercices(*variables, exo=2)

# %% [markdown]
# ***
# ## Exercice 03.3
# ***

# %% [markdown]
# Ecrire un programme qui calcul et affiche le plus petit entier `n` tel que:
#
# $$
# (n+1)(n+2) < 2020
# $$

# %%
n=0

while (n+1)*(n+2) < 2020:
    n=n+1
    
print("le plus grand entier naturel n est : ", n-1)
# Out:
# le plus grand entier naturel n est :  44

# %% [markdown]
# ### *Test*

# %%
""" Test la valeur de n """
variables = globals().copy().items()
TestsTD3.exercices(*variables, exo=3)

# %% [markdown]
# ***
# ## Exercice 03.4
# ***

# %% [markdown]
# Nous savons qu’un capital $C_{0}$ placé à 5 % rapporte au bout d'un an $C_{0}\times0,05$ d'intérêts.
#
# Ces intérêts ajoutés au capital nous donnent un nouveau capital $C_{1}= 1,05 \times$ $C_{0}$ .
#
# En recommençant le processus chaque année, on crée ainsi une suite géométrique de raison 1,05 car : $C_{k+1}= 1,05\times$$C_{k}$ .
#
# Réalisez un programme permettant de calculer le capital obtenu au bout d’un nombre d’années `N` avec un Capital initial `C0` et un taux d’intérêt `taux`. Les variables `N`, `C0` et `taux` doivent être saisies par l'utlisatuer. Le programme affichera le capital `C` correspondant à chaque année.

# %%
N=int(input("veuillez saisir le nombre d'année : "))

C0=float(input("Donner le capital initial C0 : "))

T=float(input("Quel est le taux d'intérêt ? "))

C=C0

for i in range(1,N+1) :
    C = C * (1 + T/100)
    print ("le capital obtenu au bout de l'année %d " %i,"est de %f euros" %C )

# %% [markdown]
# ### *Test*
# *Testez avec les paramètres `N=3`, `C0=20000` et `taux=2`.*

# %%
""" Test la valeur du capital C """
variables = globals().copy().items()
TestsTD3.exercices(*variables, exo=4)

# %% [markdown]
# ***
# ## Exercice 03.5
# ***

# %% [markdown]
# On considère la suite définie par récurrence de la façon suivante:
#
# $$x_{k+1}=\frac{1}{2}(x_{k}+\frac{a_{k}}{x_{k}})$$
#
# Réalisez un programme permettant de calculer l’élément `x` tandis que les variables `a`,`x0` et `k` seront renseignées au clavier par l'utilisateur. Afficher `x`.

# %%
x0= int(input("veuillez saisir x0 : "))

k= int(input("veuillez saisir k : "))

a= int(input("veuillez saisir a : "))

x=x0

for i in range (1, k+1) :
    x = 0.5 * (x + a / x)
    
print(x)

# %% [markdown]
# ### *Test*
# *Testez avec les paramètres `x0=3`, `k=6` et `a=9`.*

# %%
""" Test la valeur de x """
variables = globals().copy().items()
TestsTD3.exercices(*variables, exo=5)

# %% [markdown]
# ***
# ## Exercice 03.6
# ***

# %% [markdown]
# Ecrivez un programme qui calcule le nombre de lettres qui composent une variable `mot` que vous définirez. Le résultat sera stocké derrière la variable `nbre_ltre`.

# %%
mot="algorithmie"

nbre_ltre=0

for lettre in mot:
    nbre_ltre+=1
    
print(nbre_ltre)

# %% [markdown]
# ### *Test*
# *Testez le programme avec `mot = "algorithmie"`.*

# %%
""" Test la valeur de nbre_ltr """
variables = globals().copy().items()
TestsTD3.exercices(*variables, exo=6)

# %% [markdown]
# ***
# ## Exercice 03.7
# ***

# %% [markdown]
# Une séquence d'ADN valide signifie qu'elle n’est pas vide et est formée exclusivement d'une combinaison arbitraire de "A", "C", "G" ou "T" (A pour Adénine, C pour Cytosine, G pour Guanine et T pour Thymine).
#
# Proposez un programme qui, après avoir demandé à l’utilisateur de saisir au clavier une chaîne d'ADN `adn`, stocke derrière la variable `res` la chaîne de caractère `ADN valide` si la chaine saisie est bien une chaîne d’ADN. Le programme stockera `ADN non valide` le cas échéant.

# %%
adn=input("veuillez saisir la chaîne d'ADN : ")

err=0

for c in adn:
    if (c!="A" and c!="C" and c!="G" and c!="T"):
        err+=1
        
if len(adn)!=0 and err==0:
    res="ADN valide"
    print("ADN valide")
    
else :
    res="ADN non valide"
    print("ADN non valide, il y a ",err, " caractères erronés")

# %% [markdown]
# ### *Test*
# *Testez en entrant successivement C,T,G,G,A,C,T.*

# %%
""" Test la valeur de res """
variables = globals().copy().items()
TestsTD3.exercices(*variables, exo=7)
