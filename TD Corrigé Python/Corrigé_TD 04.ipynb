# %% [markdown]
# ***
# # IAS1 Corrigé TD 04 - Les structures de données 1
# ***

# %% [markdown]
# ***
# ### Tests automatiques

# %%
# Exécutez cette cellule pour charger le script de tests automatiques du TD
import sys
sys.path.append('Tests_TD')
import TestsTD4

# %% [markdown]
# ***
# ## Exercice 04.1
# ***

# %% [markdown]
# Ecrivez un programme qui calcule et stocke dans une liste `Liste2` le double des éléments contenus dans une liste `Liste`.

# %%
Liste=[7,2,11,5,8]

Liste2=[]

for nbr in Liste:
    Liste2 += [nbr*2]
    
    #ou Liste2.append(nbr*2)

print(Liste2)

# %% [markdown]
# ### *Test*
# *Testez avec `Liste = [7,2,11,5,8]`.*

# %%
""" Test la valeur de Liste2 """
variables = globals().copy().items()
TestsTD4.exercices(*variables, exo=1)

# %% [markdown]
# ***
# ## Exercice 04.2
# ***

# %% [markdown]
# Ecrivez un programme qui stocke dans une liste `L2` les éléments impairs d'une liste `L` en partant de la fin de la liste.

# %%
L = [4,9,23,16,12,5,4]

L2=[]

for nbr in L:
    if nbr%2!=0:      
        L2.append(nbr)

print(L2)

# %% [markdown]
# ### *Test*
# *Testez avec `L = [4,9,23,16,12,5,4]`.*

# %%
""" Test la valeur de L2 """
variables = globals().copy().items()
TestsTD4.exercices(*variables, exo=2)

# %% [markdown]
# ***
# ## Exercice 04.3
# ***

# %% [markdown]
# Ecrivez un programme qui remplisse un tableau `T` avec les 5 premières valeurs paires entrées au clavier. Affiche `T`.

# %%
T=[]

while len(T)< 5:
    val=int(input("Entrez un nombre pair : "))
    
    if val%2==0:
        T.append(val)
        
print(T)

# %% [markdown]
# ### *Test*
# *Testez en rentrant successivement 1,2,4,11,6,8,10.*

# %%
""" Test la valeur de T """
variables = globals().copy().items()
TestsTD4.exercices(*variables, exo=3)

# %% [markdown]
# ***
# ## Exercice 04.4
# ***

# %% [markdown]
# Ecrivez un programme qui demande un nombre (entier ou réel) à rentrer au clavier tant que celui-ci n’est pas négatif. Les nombres (positifs) seront stockés dans un tableau `tab`. Afficher `tab`.

# %%
tab=[]

data=float(input("Entrez un nombre : "))

while data>=0:
    tab.append(data)
    data=float(input("Entrez un nombre : "))
    
print(tab)

# %% [markdown]
# ### *Test*
# *Testez en entrant successivement 7,4.8,13,-2.*

# %%
""" Test la valeur de tab """
variables = globals().copy().items()
TestsTD4.exercices(*variables, exo=4)

# %% [markdown]
# ***
# ## Exercice 04.5
# ***

# %% [markdown]
# Ecrivez un programme qui calcule la moyenne `moy` d’un tableau de 5 valeurs réelles saisies au clavier. Afficher cette moyenne.

# %%
tab=[]

while len(tab) < 5:
    nbr=float(input("Entrez une valeur : "))
    tab.append(nbr)

somme=0
moy=0

for val in tab:
    somme += val

moy=somme/len(tab)

print(moy)

# %% [markdown]
# ### *Test*
# *Testez en entrant successivement 12,15.5,7,9.5,11.*

# %%
""" Test la valeur de moy """
variables = globals().copy().items()
TestsTD4.exercices(*variables, exo=5)

# %% [markdown]
# ***
# ## Exercice 04.6
# ***

# %% [markdown]
# Ecrivez un programme qui permute la première et la dernière valeur d'un tableau `T`.

# %%
T = [8,4,6,3]

Temp = T[-1]

T[-1] = T[0]

T[0] = Temp

print(T)

# %% [markdown]
# ### *Test*
# *Testez avec `T = [8,4,6,3]`*

# %%
""" Test la valeur de T """
variables = globals().copy().items()
TestsTD4.exercices(*variables, exo=6)

# %% [markdown]
# ***
# ## Exercice 04.7
# ***

# %% [markdown]
# Ecrivez un programme qui affecte la valeur `True` à une variable `var` si une liste `Array` possède des valeurs uniques. Le programme affectera la valeur `False` le cas échéant.

# %%
Array = [2,6,15,9,6,17]

var=True

for i in range (len(Array)-1):
    for j in range (i+1,len(Array)):
        
        if Array[i]==Array[j]:
            var=False
            
print(var)

# %% [markdown]
# ### *Test*
# *Testez avec `Array = [2,6,15,9,6,17]`.*

# %%
""" Test la valeur de la variable var """
variables = globals().copy().items()
TestsTD4.exercices(*variables, exo=7)
