# %% [markdown]
# ***
# # IAS1 Corrigé TD 02 - Les structures conditionnelles
# ***

# %% [markdown]
# ***
# ## Exercice 02.1
# ***

# %% [markdown]
# Ecrivez un programme qui demande à l’utilisateur de saisir au clavier un nombre entier `nbr` et qui affiche si ce nombre est pair ou pas.

# %%
nbr=int(input("Veuillez saisir un nombre ?"))

if nbr%2==0:
    print("le nombre saisi est pair")
    
else:
    print("le nombre saisi est impair")

# %% [markdown]
# ***
# ## Exercice 02.2
# ***

# %% [markdown]
# Ecrivez un programme python qui demande à saisir un nombre réel `R` puis calcule et affiche sa racine carrée. Attention, si le nombre saisi est négatif, le programme doit afficher un message d’erreur.

# %%
R=float(input("Veuillez saisir un nombre réel ?"))

if R>=0:
    resultat=R**(0.5)
    print("la racine carrée de ", R, "est : ",resultat)
    
else :
    print("Erreur le nombre saisi est négatif")

# %% [markdown]
# ***
# ## Exercice 02.3
# ***

# %% [markdown]
# On considère les critères d'évaluations suivants qui attribue une mention en fonction de la note évaluée sur 100 points :
#
# | Mention          | Note  (/100)           |
# | ---------------- | ---------------------- |
# | Excellent        | $\ge 82$               |
# | Très bien        | $\ge 76.5$ and $< 82$  |
# | Bien             | $\ge 66$ and $< 76.5$  |
# | Besoin de travail| $\ge 45$ and $< 66$    |
# | Avez-vous essayé?| $< 45$                 |
#
# Ecrivez un programme qui, en fonction d'une note entrée par l'utilisateur, affiche la mention associée. Affichez un message d'erreur si la note entrée par l'utilisateur est supérieur à 100 ou inférieure à 0.

# %%
note=float(input("Entrez la note obtenue"))

if note<0 or note>100:
    print("Erreur : La note doit être comprise entre 0 et 100")

else:
    
    mention=""

    if note >= 82:
        mention="Excellent"

    elif note>=76.5 and note<82:
        mention="Très bien"

    elif note>=66 and note<76.5:
        mention="Bien"

    elif note>=45 and note<66:
        mention="Besoin de travail"

    elif note<45:
        mention="Avez-vous essayé?"

    print("Avec une note obtenue de",note,", vous obtenez la mention",'"',mention,'"')
# Out:
# Entrez la note obtenue35
# Avec une note obtenue de 35.0 , vous obtenez la mention " Avez-vous essayé? "

# %% [markdown]
# ***
# ## Exercice 02.4
# ***

# %% [markdown]
# Une compagnie de transport applique une réduction au tarif initial d’un billet de transport en fonction de l’âge du voyageur :
# - Gratuit pour les moins de 2 ans ;
# - Réduction de 50% pour les enfants de 2 à 10 ans ;
# - Réduction de 30% pour les 10 à 18 ans ;
# - Réduction de 40% pour les 60 ans et plus.
#
# Écrivez un programme qui :
# - Demande à l’utilisateur de saisir au clavier son nom, prénom, sexe, âge ainsi que le tarif initial du billet ;
# - Calcule puis affiche un message comportant le nom prénom du voyageur, la réduction appliquée selon sa tranche d’âge ainsi que le tarif final qu’il doit payer.
#
# **Exemples d’affichage :**
#
# Bonjour Madame Anne Dubois. Compte tenu de votre tranche d’âge, vous bénéficiez d’une réduction de 30%. Vous paierez donc un tarif de 52.5 euros.
#
# Bonjour Monsieur Pierre Dupont. Compte tenu de votre tranche d’âge, vous bénéficiez d’une réduction de 60%. Vous paierez donc un tarif de 45 euros.

# %%
nom = input("Veuillez saisir votre nom : ")

prenom = input("Veuillez saisir votre prénom : ")

sexe=input("quel est votre sexe ? veuillez taper F pour féminin et M pour masculin : " )

age = int(input("Veuillez saisir votre âge : "))

prix = float(input("Veuillez saisir le prix initial du billet : "))

if age<2:
    reduction=100
    
elif age<=10:
    reduction=50
    
elif age<18:
    reduction=30
    
elif age>60:
    reduction=40
    
else :
    reduction=0

prixfinal=prix*(100-reduction)/100

if sexe=="F":
    s="Madame"
    
if sexe=="M":
    s="Monsieur"
    
print("Bonjour",s,nom,prenom,". Compte tenu de votre tranche d’âge, vous bénéficiez d’une réduction de",
      reduction,"%. Vous paierez donc un tarif de",prixfinal,"euros.")

# %% [markdown]
# ***
# ## Exercice 02.5
# ***

# %% [markdown]
# Un rectangle dans un plan est défini par les coordonnées de deux points (x1, y1) et (x2, y2) initialisés à votre convenance par saisie clavier.
#
# Ecrivez un programme qui :
# - Demande à saisir les coordonnées d’un troisième point (X, Y) ;
# - Affiche si ce point (X, Y) se trouve inclus dans le rectangle ou pas en utilisant une valeur booléenne pour l’affichage.

# %%
x1=float(input("Donner la valeur de x1 :"))
y1=float(input("Donner la valeur de y1 :"))
x2=float(input("Donner la valeur de x2 :"))
y2=float(input("Donner la valeur de y2 :"))

x=float(input("Donner la valeur de x :"))
y=float(input("Donner la valeur de y :"))

if (x < x1 and x < x2) or (x > x1 and x > x2) :
        Resultat = False
        
elif (y < y1 and y < y2) or (y > y1 and y > y2):
        Resultat = False
        
else :
        Resultat = True
print("Le point (x,y) est-il inclus dans le rectangle ?",Resultat)

# %% [markdown]
# ***
# ## Exercice 02.6
# ***

# %% [markdown]
# Ecrivez un programme qui :
#
# - Demande à l’utilisateur d’entrer trois longueurs a, b, c ;
#
# - Affiche si l’on peut construire un triangle à partir de ces trois points ;
#
# - Détermine si ce triangle est rectangle, isocèle, équilatéral ou quelconque.
#
# **Attention :** un triangle rectangle peut être isocèle.
#
# **Rappel :** Il n'est possible de construire un triangle que si chaque côté a une longueur inférieure à la somme des deux autres

# %%
a= float(input("Veuillez entrer la longueur du 1er côté : ")) 
b=float(input("Veuillez entrer la longueur du 2nd côté : ")) 
c = float(input("Veuillez entrer la longueur du 3ème côté : "))

# Il n'est possible de construire un triangle que si chaque côté 
# a une longueur inférieure à la somme des deux autres :

if a < (b+c) and b < (a+c) and c < (a+b) : 
  print("Ces trois longueurs déterminent bien un triangle.")

else: 
  print("Il est impossible de construire un tel triangle !") 
  exit()      # sortir du programme. 
 
quelconque = True

if a == b and b == c : 
  print("Ce triangle est équilatéral.") 
  quelconque = False
    
elif a == b or b == c or c == a : 
  print("Ce triangle est isocèle.") 
  quelconque = False
    
if a*a + b*b == c*c or b*b + c*c == a*a or c*c + a*a == b*b : 
  print("Ce triangle est rectangle.") 
  quelconque = False
    
if quelconque : 
  print("Ce triangle est quelconque.")

# %% [markdown]
# ***
# ## Exercice 02.7
# ***

# %% [markdown]
# Ecrivez un programme qui affiche si vous êtes majeur en fonction de votre jour/mois/année de naissance et de la date d’aujourd’hui.

# %%
AA=2019
MA=10
JA=4
AN=int(input("Donner l'année de votre naissance :"))
MN=int(input("Donner le mois de votre naissance :"))
JN=int(input("Donner le jour de votre naissance :"))
Majorite = 18

if AA - AN < Majorite :
    print("vous êtes mineur")
    
elif AA - AN > Majorite :
    print("vous êtes majeur")
    
elif MN > MA or (MN == MA and JN > JA) :
    print("vous êtes mineur")
    
else:
    print("vous êtes majeur")

# %% [markdown]
# ***
# ## Exercice 02.8
# ***

# %% [markdown]
# Ecrivez un programme qui détermine si une année (dont le millésime est introduit par l’utilisateur) est bissextile ou non.
#
# **Rappel :** Une année A est bissextile si A est divisible par 4. Elle ne l’est cependant pas si A est un multiple de 100, à moins que A ne soit multiple de 400.

# %%
A = int(input("Veuillez entrer l'année à tester :")) 
 
if A % 4 != 0: 
  # A n'est pas divisible par 4 -> année non bissextile 
  bs = 0
    
else:
    
  if A % 400 ==0: 
      # A divisible par 400 -> année bissextile 
      bs = 1
    
  elif A % 100 ==0: 
      # A divisible par 100 -> année non bissextile 
      bs = 0
    
  else: 
      # autres cas où A est divisible par 4 -> année bissextile 
      bs = 1
    
if bs ==1: 
  ch = "est"

else: 
  ch = "n'est pas"

print("L'année", A, ch, "bissextile.")
