# %% [markdown]
# ***
# # IAS1 TD 11 - Recherche dans une liste et complexité
# ***

# %% [markdown]
# ***
# ### Tests automatiques

# %%
# Exécutez cette cellule pour charger les scripts des tests automatiques de chaque exercice
import sys
sys.path.append('Corrigés/Tests_TD')
import TestsTD11

# %% [markdown]
# ***
# ## Exercice 11.1
# ***

# %% [markdown]
# Ecrivez une fonction `RechSeq()` qui effectue une recherche séquentielle de `x` parmi les éléments d’une liste `L`. Cette fonction renverra une variable booléenne qui prendra la valeur  `True` si l'élément est trouvé dans la liste ou `False` dans le cas contraire.

# %%
# VOTRE CODE ICI

# %% [markdown]
# ### *Test*

# %%
""" Test la fonction RechSeq() """
variables = globals().copy().items()
TestsTD11.exercices(*variables, exo=1)

# %% [markdown]
# ***
# ## Exercice 11.2
# ***

# %% [markdown]
# 1. Écrivez une fonction `maxi()` prenant en argument une liste d'entiers naturels `L` et renvoyant le maximum des entiers de cette liste (on n'utilisera pas de fonction spécifique de Python déterminant ce maximum).

# %%
# VOTRE CODE ICI

# %% [markdown]
# ### *Test*

# %%
""" Test la fonction maxi() """
variables = globals().copy().items()
TestsTD11.exercices(*variables, exo=2)

# %% [markdown]
# 2. Quelle est le nombre d'opérations élémentaires effectué par cette fonction en fonction de la longueur n de la liste?

# %% [markdown]
# *Entrez votre réponse ici*

# %% [markdown]
# ***
# ## Exercice 11.3
# ***

# %% [markdown]
# Écrivez une fonction `Minus()` prenant en argument une liste `Liste` et une variable `x`, et qui retourne le plus petit indice `k` de la liste tel que `Liste[k]` soit égal à `x`. Si la liste ne contient pas `x`, alors la fonction doit retourner `-1`.

# %%
# VOTRE CODE ICI

# %% [markdown]
# ### *Test*

# %%
""" Test la fonction minus() """
variables = globals().copy().items()
TestsTD11.exercices(*variables, exo=3)

# %% [markdown]
# ***
# ## Exercice 11.4
# ***

# %% [markdown]
# Écrivez une fonction qui `Ins()` prend en argument une liste triée `l` et un entier `elt` et qui renvoie la liste triée obtenue par insertion à sa place de `elt` dans `l`. On fera attention à ce que la liste `l` puisse être vide.

# %%
# VOTRE CODE ICI

# %% [markdown]
# ### *Test*

# %%
""" Test la fonction Ins() """
variables = globals().copy().items()
TestsTD11.exercices(*variables, exo=4)

# %% [markdown]
# ***
# ## Exercice 11.5
# ***

# %% [markdown]
# 1. Ecrivez une fonction de recherche itérative par dichotomie `Rech_dich_iter()` appliqué à la recherche d'une valeur `element` dans une liste `liste_triee`.

# %%
# VOTRE CODE ICI

# %% [markdown]
# ### *Test*

# %%
""" Test la fonction Rech_dich_iter() """
variables = globals().copy().items()
TestsTD11.exercices(*variables, exo=5.1)

# %% [markdown]
# 2. Ecrivez une fonction de recherche récursive par dichotomie `Rech_dich_rec()` appliqué à la recherche d'une valeur `element` dans une liste `liste_triee`.

# %%
# VOTRE CODE ICI

# %% [markdown]
# ### *Test*

# %%
""" Test la fonction Rech_dich_rec() """
variables = globals().copy().items()
TestsTD11.exercices(*variables, exo=5.2)

# %% [markdown]
# ***
# ## Exercice 11.6
# ***

# %% [markdown]
# Calculez la complexité de l'algorithme suivant :
#
# ```python
# for i in range (m) :
#     for j in range (n) :
#         print(j-n)```

# %% [markdown]
# *Entrez votre réponse ici*

# %% [markdown]
# ***
# ## Corrigé du TD 11
#
# Vous pouvez retrouver le corrigé de ce TD [ici](Corrigés/Corrigé_TD%2011.ipynb).
