# %% [markdown]
# ***
# # IAS1 TD 12 - TP 02 Blanc
# ***

# %% [markdown]
# ***
# ## Consignes
#
# - Vous disposez de 2 heures pour réaliser ce sujet ;
# - Les 5 exercices suivants sont indépendants :
#     - <a href="#Exercice-01---Produit-scalaire">Exercice 01 - Produit scalaire</a>
#     - <a href="#Exercice-02---Table-de-multiplication">Exercice 02 - Table de multiplication</a>
#     - <a href="#Exercice-03---Fichier-txt">Exercice 03 -  Fichier txt</a>
#     - <a href="#Exercice-04---Fonction-itérative/récursive">Exercice 04 - Fonction itérative/récursive</a>
#
# - Sauvegardez régulièrement votre travail;
# - A la fin de l'examen, envoyez votre notebook Nom_prenom_TP2_2020.ipynb à partir du lien fourni par votre enseignant.
# ***

# %% [markdown]
# ***
# ### Tests automatiques

# %%
# Exécutez cette cellule pour charger le script de tests automatiques du TD
import sys
sys.path.append('Corrigés/Tests_TD')
import TestsTD12

# %% [markdown]
# ***
# ## Exercice 01 - Produit scalaire
# ***

# %% [markdown]
# Le produit scalaire du vecteur u de coordonnées (x,y,z) par v de coordonnées (x',y',z') est égal à :
#
# $$
# xx'+yy'+zz'
# $$
#
# Par exemple, le produit scalaire de u = (2,2,−1) par v = (3,−2,5) est :
#
# $$
# 2∗3 + 2∗(−2) + (−1)∗5 = −3
# $$
#
# **En assimilant les vecteurs à des listes**, écrire une fonction `produit_scalaire()` qui calcule le produit scalaire de `u` par `v` passés en paramètres.
#
# Cette fonction retournera le produit scalaire de `u` par `v` stocké derrière la variable `res`. Dans le cas où `u` et `v` ne sont pas de même longueur, la fonction affichera `"erreur: u et v n'ont pas la même longueur"` et `res` prendra la valeur 0.

# %%
# VOTRE CODE ICI

# %% [markdown]
# ### *Test*

# %%
""" Test la valeur du produit scalaire calculé """
variables = globals().copy().items()
TestsTD12.exercices(*variables, exo=1)

# %% [markdown]
# ***
# ## Exercice 02 - Table de multiplication
# ***

# %% [markdown]
# 1. On souhaite écrire une fonction `Table()` qui crée un fichier texte `Table_de_multiplication.txt` et qui enregistre dans ce fichier la table de multiplication du nombre entré en paramètre.
#
# Par exemple, l'appel de la fonction Table(5) écrira à la suite du fichier `Table_de_multiplication.txt` :
#
# La table de multiplication de 5 est :
#
#
# 0 x 5 = 0
#
# 1 x 5 = 5
#
# 2 x 5 = 10
#
# 3 x 5 = 15
#
# 4 x 5 = 20
#
# 5 x 5 = 25
#
# 6 x 5 = 30
#
# 7 x 5 = 35
#
# 8 x 5 = 40
#
# 9 x 5 = 45
#
# 10 x 5 = 50
#
#
# Ecrivez la fonction `Table()`.

# %%
# VOTRE CODE ICI

# %% [markdown]
# 2. Complétez la fonction `Table()` pour qu'elle retourne la somme `S` de tous les résultats de la table de multiplication.

# %%
# VOTRE CODE ICI

# %% [markdown]
# ### *Test*

# %%
""" Test la valeur de S """
variables = globals().copy().items()
TestsTD12.exercices(*variables, exo=2.2)

# %% [markdown]
# ***
# ## Exercice 03 - Fichier txt
# ***

# %% [markdown]
# 1. Ecrivez une fonction `countLine()` renvoyant le nombre de lignes d'un fichier dont le nom est passé en paramètre.

# %%
# VOTRE CODE ICI

# %% [markdown]
# 2. En utilisant la fonction précédente `countLine()`, écrivez une fonction `tail()` affichant les `n` dernieres lignes d'un fichier dont le nom et le nombre `n` de lignes souhaitées sont passés en paramètre (par défaut la fonction affichera 10 lignes).

# %%
# VOTRE CODE ICI

# %% [markdown]
# 3. Ecrire une fonction nommée `head()` renvoyant les `n` premières lignes d'un fichier pour un nombre `n` passé en paramètre (par défaut la fonction affichera 10 lignes).

# %%
# VOTRE CODE ICI

# %% [markdown]
# ***
# ## Exercice 04 - Fonction itérative/récursive
# ***

# %% [markdown]
# On considère la fonction `sommation_inverse()` qui calcule la somme des inverses carrés des `n` premiers entiers naturels non nuls. Le nombre `n` est passé en paramètres.
# $$
# \sum_{i=1}^{n} (\frac{1}{i^{2}})
# $$
#
# 1. Ecrivez une version itérative de la fonction que vous nommerez `sommation_inverse_iter()`.

# %%
# VOTRE CODE ICI

# %% [markdown]
# ### *Test*

# %%
""" Test la fonction sommation_inverse_iter() """
variables = globals().copy().items()
TestsTD12.exercices(*variables, exo=4.1)

# %% [markdown]
# 2. Ecrivez une version récursive de la fonction que vous nommerez `sommation_inverse_rec()`.

# %%
# VOTRE CODE ICI

# %% [markdown]
# ### *Test*

# %%
""" Test la fonction sommation_inverse_rec() """
variables = globals().copy().items()
TestsTD12.exercices(*variables, exo=4.2)

# %% [markdown]
# ***
# <center><b>Une fois l'épreuve terminée, téléchargez votre notebook sur votre ordinateur puis uploadez le à partir du lien fourni par votre enseignant</center></b>

# %% [markdown]
# ***
# ## Corrigé du TD 12
#
# Vous pouvez retrouver le corrigé de ce TD [ici](Corrigés/Corrigé_TD%2012.ipynb).
